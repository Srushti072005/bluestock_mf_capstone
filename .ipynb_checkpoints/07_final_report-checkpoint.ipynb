# %%
import subprocess
subprocess.run(['pip', 'install', 'reportlab'])
print("✅ reportlab installed!")
# Out:
# ✅ reportlab installed!

# %%
from reportlab.lib.pagesizes import letter, A4
from reportlab.lib.styles import getSampleStyleSheet, ParagraphStyle
from reportlab.lib.colors import HexColor, black, white
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer, Table, TableStyle, HRFlowable
from reportlab.lib.units import inch
from reportlab.lib.enums import TA_CENTER, TA_LEFT, TA_JUSTIFY
import os

# Colors
BLUE = HexColor('#00529B')
ORANGE = HexColor('#FF8C00')
LIGHT_BLUE = HexColor('#E8F4FD')
GRAY = HexColor('#666666')

# Save path
save_path = r"C:\Users\Admin\Documents\bluestock_mf_capstone\reports\Final_Report.pdf"

# Create document
doc = SimpleDocTemplate(
    save_path,
    pagesize=A4,
    rightMargin=72,
    leftMargin=72,
    topMargin=72,
    bottomMargin=72
)

# Styles
styles = getSampleStyleSheet()

title_style = ParagraphStyle(
    'CustomTitle',
    parent=styles['Title'],
    fontSize=28,
    textColor=BLUE,
    spaceAfter=20,
    alignment=TA_CENTER,
    fontName='Helvetica-Bold'
)

heading1_style = ParagraphStyle(
    'Heading1',
    parent=styles['Heading1'],
    fontSize=18,
    textColor=BLUE,
    spaceAfter=12,
    spaceBefore=20,
    fontName='Helvetica-Bold'
)

heading2_style = ParagraphStyle(
    'Heading2',
    parent=styles['Heading2'],
    fontSize=14,
    textColor=ORANGE,
    spaceAfter=8,
    spaceBefore=12,
    fontName='Helvetica-Bold'
)

body_style = ParagraphStyle(
    'CustomBody',
    parent=styles['Normal'],
    fontSize=11,
    textColor=black,
    spaceAfter=8,
    leading=16,
    alignment=TA_JUSTIFY
)

subtitle_style = ParagraphStyle(
    'Subtitle',
    parent=styles['Normal'],
    fontSize=14,
    textColor=GRAY,
    spaceAfter=8,
    alignment=TA_CENTER
)

# Build content
content = []

# ===== PAGE 1 - TITLE =====
content.append(Spacer(1, 1*inch))
content.append(Paragraph(
    "Bluestock Mutual Fund Analytics",
    title_style))
content.append(Paragraph(
    "Capstone Project I — Final Report",
    subtitle_style))
content.append(HRFlowable(
    width="100%",
    thickness=2,
    color=BLUE))
content.append(Spacer(1, 0.3*inch))

# Author info table
author_data = [
    ['Intern Name:', 'Srushti Deshmukh'],
    ['Cohort:', 'MJ28'],
    ['Organization:', 'Bluestock Fintech'],
    ['Project:', 'Capstone Project I'],
    ['Duration:', '01 Jun 2026 — 12 Jun 2026'],
    ['GitHub:', 'github.com/Srushti072005/bluestock_mf_capstone'],
]

author_table = Table(author_data, colWidths=[2*inch, 4*inch])
author_table.setStyle(TableStyle([
    ('FONTNAME', (0,0), (-1,-1), 'Helvetica'),
    ('FONTSIZE', (0,0), (-1,-1), 11),
    ('FONTNAME', (0,0), (0,-1), 'Helvetica-Bold'),
    ('TEXTCOLOR', (0,0), (0,-1), BLUE),
    ('BOTTOMPADDING', (0,0), (-1,-1), 8),
    ('TOPPADDING', (0,0), (-1,-1), 8),
]))
content.append(author_table)
content.append(Spacer(1, 0.5*inch))

# ===== EXECUTIVE SUMMARY =====
content.append(HRFlowable(width="100%", thickness=1, color=BLUE))
content.append(Spacer(1, 0.2*inch))
content.append(Paragraph("1. Executive Summary", heading1_style))
content.append(Paragraph(
    "This report presents a comprehensive analysis of mutual fund data "
    "for Bluestock Fintech's Capstone Project I. The project involved "
    "building an end-to-end data analytics pipeline using Python, SQLite, "
    "and Power BI to analyze NAV trends, performance metrics, and risk "
    "analytics for 5 key mutual fund schemes.",
    body_style))
content.append(Paragraph(
    "The analysis covers data ingestion from mfapi.in API, data cleaning, "
    "exploratory data analysis with 15 charts, SQL database design with "
    "10 analytical queries, Power BI interactive dashboard with 4 pages, "
    "and advanced risk analytics including VaR, CVaR, and Sharpe Ratio.",
    body_style))

# ===== DATA SOURCES =====
content.append(Paragraph("2. Data Sources", heading1_style))
content.append(Paragraph("2.1 Datasets Used", heading2_style))

data_sources = [
    ['Dataset', 'Source', 'Records', 'Description'],
    ['fund_master.csv', 'mfapi.in', '15', 'Fund scheme information'],
    ['nav_history.csv', 'mfapi.in API', '150', 'Historical NAV data'],
    ['live_nav.csv', 'mfapi.in API', '5', 'Latest NAV values'],
]

data_table = Table(data_sources, 
    colWidths=[1.8*inch, 1.8*inch, 1*inch, 2.4*inch])
data_table.setStyle(TableStyle([
    ('BACKGROUND', (0,0), (-1,0), BLUE),
    ('TEXTCOLOR', (0,0), (-1,0), white),
    ('FONTNAME', (0,0), (-1,0), 'Helvetica-Bold'),
    ('FONTSIZE', (0,0), (-1,-1), 10),
    ('BACKGROUND', (0,1), (-1,-1), LIGHT_BLUE),
    ('ROWBACKGROUNDS', (0,1), (-1,-1), [white, LIGHT_BLUE]),
    ('GRID', (0,0), (-1,-1), 0.5, GRAY),
    ('BOTTOMPADDING', (0,0), (-1,-1), 8),
    ('TOPPADDING', (0,0), (-1,-1), 8),
    ('ALIGN', (0,0), (-1,-1), 'CENTER'),
]))
content.append(data_table)
content.append(Spacer(1, 0.3*inch))

content.append(Paragraph("2.2 Key Schemes Analyzed", heading2_style))
schemes_data = [
    ['Scheme Name', 'AMFI Code', 'Category'],
    ['SBI Bluechip Fund', '119551', 'Large Cap'],
    ['ICICI Prudential Bluechip', '120503', 'Large Cap'],
    ['Nippon Large Cap Fund', '118632', 'Large Cap'],
    ['Axis Bluechip Fund', '119092', 'Large Cap'],
    ['Kotak Bluechip Fund', '120841', 'Large Cap'],
]

schemes_table = Table(schemes_data,
    colWidths=[3*inch, 1.5*inch, 2.5*inch])
schemes_table.setStyle(TableStyle([
    ('BACKGROUND', (0,0), (-1,0), BLUE),
    ('TEXTCOLOR', (0,0), (-1,0), white),
    ('FONTNAME', (0,0), (-1,0), 'Helvetica-Bold'),
    ('FONTSIZE', (0,0), (-1,-1), 10),
    ('ROWBACKGROUNDS', (0,1), (-1,-1), [white, LIGHT_BLUE]),
    ('GRID', (0,0), (-1,-1), 0.5, GRAY),
    ('BOTTOMPADDING', (0,0), (-1,-1), 8),
    ('TOPPADDING', (0,0), (-1,-1), 8),
    ('ALIGN', (0,0), (-1,-1), 'CENTER'),
]))
content.append(schemes_table)

# ===== ETL PIPELINE =====
content.append(Paragraph("3. ETL Pipeline", heading1_style))
content.append(Paragraph("3.1 Data Ingestion", heading2_style))
content.append(Paragraph(
    "The data ingestion pipeline was built using Python and the requests "
    "library to fetch live NAV data from mfapi.in API. The pipeline "
    "successfully loaded all 3 CSV datasets and fetched live NAV for "
    "5 key schemes.",
    body_style))

content.append(Paragraph("3.2 Data Cleaning", heading2_style))
content.append(Paragraph(
    "Data cleaning involved parsing dates with dayfirst=True, removing "
    "duplicates, forward-filling missing NAV values for holidays/weekends, "
    "and validating NAV > 0. All cleaned datasets were saved to "
    "data/processed/ folder.",
    body_style))

etl_data = [
    ['Step', 'Task', 'Status'],
    ['1', 'Load CSV datasets', '✅ Complete'],
    ['2', 'Fetch live NAV from API', '✅ Complete'],
    ['3', 'Parse dates (dayfirst=True)', '✅ Complete'],
    ['4', 'Remove duplicates', '✅ Complete'],
    ['5', 'Forward-fill missing NAV', '✅ Complete'],
    ['6', 'Validate NAV > 0', '✅ Complete'],
    ['7', 'Save cleaned CSVs', '✅ Complete'],
]

etl_table = Table(etl_data,
    colWidths=[0.8*inch, 4*inch, 2.2*inch])
etl_table.setStyle(TableStyle([
    ('BACKGROUND', (0,0), (-1,0), BLUE),
    ('TEXTCOLOR', (0,0), (-1,0), white),
    ('FONTNAME', (0,0), (-1,0), 'Helvetica-Bold'),
    ('FONTSIZE', (0,0), (-1,-1), 10),
    ('ROWBACKGROUNDS', (0,1), (-1,-1), [white, LIGHT_BLUE]),
    ('GRID', (0,0), (-1,-1), 0.5, GRAY),
    ('BOTTOMPADDING', (0,0), (-1,-1), 8),
    ('TOPPADDING', (0,0), (-1,-1), 8),
    ('ALIGN', (0,0), (-1,-1), 'CENTER'),
]))
content.append(etl_table)

# ===== DATABASE =====
content.append(Paragraph("4. Database Design", heading1_style))
content.append(Paragraph("4.1 SQLite Schema", heading2_style))
content.append(Paragraph(
    "A SQLite database (bluestock_mf.db) was designed with 3 tables "
    "following a star schema design pattern.",
    body_style))

db_data = [
    ['Table Name', 'Columns', 'Records'],
    ['fact_nav', 'Date, Scheme, Code, NAV', '150'],
    ['dim_fund', 'schemeCode, schemeName', '15'],
    ['fact_live_nav', 'Date, Scheme, Code, NAV', '5'],
]

db_table = Table(db_data,
    colWidths=[2*inch, 3.5*inch, 1.5*inch])
db_table.setStyle(TableStyle([
    ('BACKGROUND', (0,0), (-1,0), BLUE),
    ('TEXTCOLOR', (0,0), (-1,0), white),
    ('FONTNAME', (0,0), (-1,0), 'Helvetica-Bold'),
    ('FONTSIZE', (0,0), (-1,-1), 10),
    ('ROWBACKGROUNDS', (0,1), (-1,-1), [white, LIGHT_BLUE]),
    ('GRID', (0,0), (-1,-1), 0.5, GRAY),
    ('BOTTOMPADDING', (0,0), (-1,-1), 8),
    ('TOPPADDING', (0,0), (-1,-1), 8),
    ('ALIGN', (0,0), (-1,-1), 'CENTER'),
]))
content.append(db_table)

# ===== EDA =====
content.append(Paragraph("5. Exploratory Data Analysis", heading1_style))
content.append(Paragraph("5.1 Charts Created", heading2_style))

eda_data = [
    ['Chart', 'Type', 'Insight'],
    ['NAV Trend', 'Line Chart', 'All schemes show positive trend'],
    ['Latest NAV', 'Bar Chart', 'SBI Bluechip leads'],
    ['NAV Distribution', 'Box Plot', 'Low variance across schemes'],
    ['Correlation', 'Heatmap', 'High correlation > 0.95'],
    ['Daily Returns', 'Line Chart', 'Stable daily returns'],
    ['NAV Growth %', 'Line Chart', 'Positive growth all schemes'],
    ['Average NAV', 'Bar Chart', 'Similar averages'],
    ['NAV Share', 'Pie Chart', 'Equal distribution'],
    ['Volatility', 'Bar Chart', 'Kotak most stable'],
    ['Min Max NAV', 'Bar Chart', 'NAV range analysis'],
    ['Monthly Trend', 'Line Chart', 'Consistent monthly growth'],
    ['NAV Range', 'Error Bar', 'Min-Avg-Max range'],
    ['Records Count', 'Pie Chart', 'Equal 30 records each'],
    ['Rolling Avg', 'Line Chart', '7-day rolling average'],
    ['Live NAV', 'Bar Chart', 'Current NAV comparison'],
]

eda_table = Table(eda_data,
    colWidths=[1.8*inch, 1.8*inch, 3.4*inch])
eda_table.setStyle(TableStyle([
    ('BACKGROUND', (0,0), (-1,0), BLUE),
    ('TEXTCOLOR', (0,0), (-1,0), white),
    ('FONTNAME', (0,0), (-1,0), 'Helvetica-Bold'),
    ('FONTSIZE', (0,0), (-1,-1), 9),
    ('ROWBACKGROUNDS', (0,1), (-1,-1), [white, LIGHT_BLUE]),
    ('GRID', (0,0), (-1,-1), 0.5, GRAY),
    ('BOTTOMPADDING', (0,0), (-1,-1), 6),
    ('TOPPADDING', (0,0), (-1,-1), 6),
    ('ALIGN', (0,0), (-1,-1), 'CENTER'),
]))
content.append(eda_table)

# ===== PERFORMANCE =====
content.append(Paragraph("6. Performance Analytics", heading1_style))
content.append(Paragraph(
    "Performance analytics were computed for all 5 schemes including "
    "CAGR, Sharpe Ratio, volatility, and risk-adjusted returns.",
    body_style))

perf_data = [
    ['Metric', 'Description', 'Result'],
    ['CAGR', 'Compound Annual Growth Rate', 'Positive for all schemes'],
    ['Sharpe Ratio', 'Risk-adjusted returns', 'Computed for all'],
    ['Volatility', 'Standard deviation of returns', 'Low volatility'],
    ['VaR 95%', 'Value at Risk', 'Moderate risk'],
    ['CVaR', 'Conditional VaR', 'Computed for all'],
    ['Rolling Sharpe', '90-day rolling', 'Improving trend'],
]

perf_table = Table(perf_data,
    colWidths=[1.8*inch, 2.7*inch, 2.5*inch])
perf_table.setStyle(TableStyle([
    ('BACKGROUND', (0,0), (-1,0), BLUE),
    ('TEXTCOLOR', (0,0), (-1,0), white),
    ('FONTNAME', (0,0), (-1,0), 'Helvetica-Bold'),
    ('FONTSIZE', (0,0), (-1,-1), 10),
    ('ROWBACKGROUNDS', (0,1), (-1,-1), [white, LIGHT_BLUE]),
    ('GRID', (0,0), (-1,-1), 0.5, GRAY),
    ('BOTTOMPADDING', (0,0), (-1,-1), 8),
    ('TOPPADDING', (0,0), (-1,-1), 8),
    ('ALIGN', (0,0), (-1,-1), 'CENTER'),
]))
content.append(perf_table)

# ===== DASHBOARD =====
content.append(Paragraph("7. Power BI Dashboard", heading1_style))
content.append(Paragraph(
    "An interactive 4-page Power BI dashboard was created to visualize "
    "mutual fund analytics with slicers for dynamic filtering.",
    body_style))

dash_data = [
    ['Page', 'Title', 'Visuals'],
    ['1', 'Industry Overview', 'Line chart, KPI card, Slicer'],
    ['2', 'Fund Performance', 'Bar chart, Scatter, Slicer'],
    ['3', 'Investor Analytics', 'Pie chart, Bar chart, Slicer'],
    ['4', 'SIP & Market Trends', 'Line chart, Area chart, Slicer'],
]

dash_table = Table(dash_data,
    colWidths=[0.8*inch, 2.5*inch, 3.7*inch])
dash_table.setStyle(TableStyle([
    ('BACKGROUND', (0,0), (-1,0), BLUE),
    ('TEXTCOLOR', (0,0), (-1,0), white),
    ('FONTNAME', (0,0), (-1,0), 'Helvetica-Bold'),
    ('FONTSIZE', (0,0), (-1,-1), 10),
    ('ROWBACKGROUNDS', (0,1), (-1,-1), [white, LIGHT_BLUE]),
    ('GRID', (0,0), (-1,-1), 0.5, GRAY),
    ('BOTTOMPADDING', (0,0), (-1,-1), 8),
    ('TOPPADDING', (0,0), (-1,-1), 8),
    ('ALIGN', (0,0), (-1,-1), 'CENTER'),
]))
content.append(dash_table)

# ===== ADVANCED ANALYTICS =====
content.append(Paragraph("8. Advanced Analytics", heading1_style))
content.append(Paragraph("8.1 Risk Metrics", heading2_style))
content.append(Paragraph(
    "Advanced risk metrics were computed including Historical VaR at "
    "95% confidence level, CVaR, and Rolling 90-day Sharpe Ratio for "
    "all 5 mutual fund schemes.",
    body_style))

content.append(Paragraph("8.2 Fund Recommender", heading2_style))
content.append(Paragraph(
    "A simple fund recommender system was built that classifies funds "
    "by risk grade (Low/Moderate/High) and recommends top 3 funds "
    "based on Sharpe Ratio within each risk category.",
    body_style))

# ===== KEY FINDINGS =====
content.append(Paragraph("9. Key Findings", heading1_style))

findings = [
    "SBI Bluechip Fund shows the highest NAV growth among all schemes",
    "All 5 schemes demonstrate positive NAV trends over the analysis period",
    "High correlation (>0.95) exists between all bluechip fund schemes",
    "Kotak Bluechip Fund is the most stable with lowest volatility",
    "ICICI Bluechip Fund shows the best risk-adjusted returns (Sharpe Ratio)",
    "All schemes fall under moderate risk category based on VaR analysis",
    "Rolling Sharpe Ratio shows improving trend over 90-day window",
    "Fund Recommender successfully classifies risk and recommends funds",
    "NAV data quality is high with no missing values after cleaning",
    "SQLite database successfully stores and queries all fund data",
]

for i, finding in enumerate(findings, 1):
    content.append(Paragraph(
        f"• {finding}", body_style))

# ===== DELIVERABLES =====
content.append(Paragraph("10. Project Deliverables", heading1_style))

deliv_data = [
    ['Day', 'Deliverable', 'Status'],
    ['Day 1', '01_data_ingestion.ipynb', '✅'],
    ['Day 2', '02_data_cleaning.ipynb + bluestock_mf.db', '✅'],
    ['Day 3', '03_eda_analysis.ipynb + 15 charts', '✅'],
    ['Day 4', '04_performance_analytics.ipynb', '✅'],
    ['Day 5', 'bluestock_mf_dashboard.pbix', '✅'],
    ['Day 6', '05_advanced_analytics.ipynb', '✅'],
    ['Day 7', 'Final_Report.pdf + Presentation.pptx', '✅'],
]

deliv_table = Table(deliv_data,
    colWidths=[1*inch, 4.5*inch, 1.5*inch])
deliv_table.setStyle(TableStyle([
    ('BACKGROUND', (0,0), (-1,0), BLUE),
    ('TEXTCOLOR', (0,0), (-1,0), white),
    ('FONTNAME', (0,0), (-1,0), 'Helvetica-Bold'),
    ('FONTSIZE', (0,0), (-1,-1), 10),
    ('ROWBACKGROUNDS', (0,1), (-1,-1), [white, LIGHT_BLUE]),
    ('GRID', (0,0), (-1,-1), 0.5, GRAY),
    ('BOTTOMPADDING', (0,0), (-1,-1), 8),
    ('TOPPADDING', (0,0), (-1,-1), 8),
    ('ALIGN', (0,0), (-1,-1), 'CENTER'),
]))
content.append(deliv_table)

# ===== CONCLUSION =====
content.append(Paragraph("11. Conclusion", heading1_style))
content.append(Paragraph(
    "This capstone project successfully demonstrated an end-to-end "
    "mutual fund analytics pipeline. All 7 days of tasks were completed "
    "including data ingestion, cleaning, EDA, performance analytics, "
    "Power BI dashboard, and advanced risk metrics.",
    body_style))
content.append(Paragraph(
    "The project provides actionable insights for mutual fund investors "
    "and demonstrates proficiency in Python, SQL, data visualization, "
    "and business intelligence tools.",
    body_style))

# ===== REFERENCES =====
content.append(Paragraph("12. References", heading1_style))
content.append(Paragraph("• mfapi.in — Mutual Fund API", body_style))
content.append(Paragraph("• AMFI India — Association of Mutual Funds", body_style))
content.append(Paragraph("• Python Documentation — pandas, numpy, matplotlib", body_style))
content.append(Paragraph("• Power BI Documentation — Microsoft", body_style))
content.append(Paragraph(
    "• GitHub Repository: github.com/Srushti072005/bluestock_mf_capstone",
    body_style))

# Build PDF
doc.build(content)
print("✅ Final Report PDF created!")
print(f"📁 Saved at: {save_path}")
# Out:
# ✅ Final Report PDF created!
# 📁 Saved at: C:\Users\Admin\Documents\bluestock_mf_capstone\reports\Final_Report.pdf
